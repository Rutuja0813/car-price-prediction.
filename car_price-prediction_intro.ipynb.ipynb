# %%
import numpy as np
import streamlit as st
import pickle

# Load the trained model

with open("car_price_model.pkl", "rb") as file:
    model = pickle.load(file)



# Page configuration
st.set_page_config(page_title="Car Price Prediction", page_icon="🚗", layout="centered")

st.title("Car Price Prediction App")
st.markdown("""
This app predicts the price of a car based on various features.
Please enter the details below and click on 'Predict Price' to see the estimated price.
""")

# Input section
st.subheader("Enter Car Details")
col1, col2 = st.columns(2)

with col1:
    brand = st.selectbox("Car Brand",
                         ["audi", "bmw", "chevrolet", "honda", "hyundai", "jaguar",
                          "mazda", "mercedes", "mitsubishi", "nissan", "porsche",
                          "subaru", "toyota", "volkswagen", "volvo"])
    fueltype = st.selectbox("Fuel Type", ["gas", "diesel"])
    aspiration = st.selectbox("Aspiration", ["std", "turbo"])
    doornumber = st.selectbox("Number of Doors", ["two", "four"])
    carbody = st.selectbox("Car Body Type", ["sedan", "hatchback", "convertible", "wagon", "hardtop"])

with col2:
    drivewheel = st.selectbox("Drive Wheel", ["fwd", "rwd", "4wd"])
    enginesize = st.number_input("Engine Size (cc)", min_value=50, max_value=600, value=150)
    horsepower = st.number_input("Horsepower (HP)", min_value=40, max_value=400, value=100)
    citympg = st.number_input("City Mileage (km/l)", min_value=5, max_value=40, value=15)
    highwaympg = st.number_input("Highway Mileage (km/l)", min_value=5, max_value=50, value=20)

st.markdown("---")

if st.button("🚗 Predict Car Price"):
    # Sample input array (This will depend on your feature structure)
    # For demonstration, let's assume your model expects [enginesize, horsepower, citympg, highwaympg]
    input_data = np.array([[enginesize, horsepower, citympg, highwaympg]])

    # Predict price
    predicted_price = model.predict(input_data)[0]

    # Display result
    st.success(f"💰 Estimated Car Price: ${predicted_price:,.2f}")

    st.balloons()
# Out:
# 2026-09-12 15:04:26.547 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:26.548 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.086
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\Rutuja\Downloads\ML Model\ML Model 2\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-09-12 15:04:27.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.090 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.090 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.091 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.091 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.093 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.094 Session state does not function when running a script without `streamlit run`
# 2026-09-12 15:04:27.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.111 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.111 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.114 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 15:04:27.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
